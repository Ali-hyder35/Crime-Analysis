# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-hyder35/Crime-Analysis/blob/main/6_Copy_of_Ali_Hyder_Quiz_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Data Analysis
#
# * use sep='\t' in read_csv

# %%
data = pd.read_csv('/content/chipotle.tsv',sep="\t")

# %% [markdown]
# ### Step 1. See the first 10 entries

# %%
data.iloc[0:10]
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
# 5         3  ...     $10.98
# 6         3  ...      $1.69
# 7         4  ...     $11.75
# 8         4  ...      $9.25
# 9         5  ...      $9.25
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Step 2. What is the number of observations in the dataset?

# %%
index=data.index[:]
number_of_rows = len(index)
number_of_rows
# Out:
# 4622

# %%
# Solution 1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
# Solution 2

# %% [markdown]
# ### Step 3. What is the number of columns in the dataset?

# %%
len(data.columns)

#print (Total)
# Out:
# 5

# %% [markdown]
# ### Step 4. Print the name of all the columns.

# %%
print(data.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 5. Which was the most-ordered item?

# %%
var1=data['item_name'].value_counts()[:]
var2=var1.max()
var2
# Out:
# 726

# %%
data.groupby('item_name').sum().sort_values('quantity',ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# ### Step 6. For the most-ordered item, how many items were ordered?

# %%
data.groupby('item_name').sum().sort_values('quantity',ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# ### Step 7. What was the most ordered item in the choice_description column?

# %%
data.groupby('choice_description').sum().sort_values('quantity',ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# ### Step 8. How many items were orderd in total?

# %%
var1=data['quantity'].sum()
var2=var1.max()
var2
# Out:
# 4972

# %% [markdown]
# ### Step 9. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
data.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 13.b. change the type of item price

# %%
data['item_price'] = data['item_price'].str.replace('\$','')

# %%
data.item_price = data.item_price.astype(float)

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
df = pd.DataFrame(data)
print (df['item_price'].dtypes)
# Out:
# float64

# %% [markdown]
# ### Step 10. How much was the revenue for the period in the dataset?

# %%
#revenue= data['quantity']*data['item_price']
#revenue.count()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %%
revenue= data.item_price.sum()
revenue
# Out:
# 34500.16

# %% [markdown]
# ### Step 11. How many orders were made in the period?

# %%
z= data.groupby('order_id').sum()
z=z.sort_values(by='order_id', ascending= False).head(1)
z
# Out:
#           quantity  item_price
# order_id
# 1834             3       28.75

# %% [markdown]
# ### Step 12. What is the average revenue amount per order?

# %%
data.groupby('item_price').order_id.mean().mean()
# Out:
# 1007.6937168071478

# %%
# Out:
# 21.394231188658654

# %%
#revenue= data.quantity.sum(
data.item_price
#avg = revenue/count
#avg

# %%
# Solution 1

# %% [markdown]
# ### Step 13. How many different items are sold?

# %%
len(data.item_name.unique())
# Out:
# 50

# %% [markdown]
# ## Filteration and Sorting

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Euro_2012_stats_TEAM.csv')

# %%
df.head()
# Out:
#              Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 0         Croatia      4               13  ...        9        9           16
# 1  Czech Republic      4               13  ...       11       11           19
# 2         Denmark      4               10  ...        7        7           15
# 3         England      5               11  ...       11       11           16
# 4          France      3               22  ...       11       11           19
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Step 2. Assign it to a variable called euro12.

# %%
#df.assign(euro12 = 12)
euro_12=df
euro_12.head()
# Out:
#              Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 0         Croatia      4               13  ...        9        9           16
# 1  Czech Republic      4               13  ...       11       11           19
# 2         Denmark      4               10  ...        7        7           15
# 3         England      5               11  ...       11       11           16
# 4          France      3               22  ...       11       11           19
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Step 2. Select only the Goal column.

# %%
#euro_12.Goals
euro_12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### Step 3. How many team participated in the Euro2012?

# %%
euro_12.Team.count()
# Out:
# 16

# %% [markdown]
# ### Step 4. What is the number of columns in the dataset?

# %%
euro_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %% [markdown]
# ### Step 5. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline=euro_12.iloc[:,[0,30,31]]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Step 6. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline=euro_12.rename(columns={'Red Cards':'Red_cards','Yellow Cards':'Yellow_Cards'})
euro_12.sort_values('Red_cards',ascending=False)
# Out:
#                    Team  Goals  ...  Subs off  Players Used
# 6                Greece      5  ...        12            20
# 9                Poland      2  ...         7            17
# 11  Republic of Ireland      1  ...        10            17
# 0               Croatia      4  ...         9            16
# 1        Czech Republic      4  ...        11            19
# 2               Denmark      4  ...         7            15
# 3               England      5  ...        11            16
# 4                France      3  ...        11            19
# 5               Germany     10  ...        15            17
# 7                 Italy      6  ...        18            19
# 8           Netherlands      2  ...         7            15
# 10             Portugal      6  ...        14            16
# 12               Russia      5  ...         7            16
# 13                Spain     12  ...        17            18
# 14               Sweden      5  ...         9            18
# ...

# %% [markdown]
# ### Step 7. Calculate the mean Yellow Cards given per Team

# %%
euro_12.Yellow_Cards.mean()
# Out:
# 7.4375

# %% [markdown]
# ### Step 8. Filter teams that scored more than 6 goals

# %%
filter_team=euro_12['Goals']>6
euro_12[filter_team]
# Out:
#        Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 5   Germany     10               32  ...       15       15           17
# 13    Spain     12               42  ...       17       17           18
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Step 9. Select the teams that start with G

# %%
euro_12[euro_12['Team'].str[0] == 'G']
# Out:
#       Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 5  Germany     10               32  ...       15       15           17
# 6   Greece      5                8  ...       12       12           20
#
# [2 rows x 35 columns]

# %%
team_Name=euro_12['Team']=='G'
euro_12[team_Name]
# Out:
# Empty DataFrame
# Columns: [Team, Goals, Shots on target, Shots off target, Shooting Accuracy, % Goals-to-shots, Total shots (inc. Blocked), Hit Woodwork, Penalty goals, Penalties not scored, Headed goals, Passes, Passes completed, Passing Accuracy, Touches, Crosses, Dribbles, Corners Taken, Tackles, Clearances, Interceptions, Clearances off line, Clean Sheets, Blocks, Goals conceded, Saves made, Saves-to-shots ratio, Fouls Won, Fouls Conceded, Offsides, Yellow_Cards, Red_cards, Subs on, Subs off, Players Used]
# Index: []

# %% [markdown]
# ### Step 10. Select the first 7 columns

# %%
euro_12[euro_12.columns[0:7]].head()
# Out:
#              Team  Goals  ...  % Goals-to-shots  Total shots (inc. Blocked)
# 0         Croatia      4  ...             16.0%                          32
# 1  Czech Republic      4  ...             12.9%                          39
# 2         Denmark      4  ...             20.0%                          27
# 3         England      5  ...             17.2%                          40
# 4          France      3  ...              6.5%                          65
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Step 11. Select all columns except the last 3.

# %%
euro_12[euro_12.columns[:-3]].head()
# Out:
#              Team  Goals  Shots on target  ...  Offsides Yellow_Cards Red_cards
# 0         Croatia      4               13  ...         2            9         0
# 1  Czech Republic      4               13  ...         8            7         0
# 2         Denmark      4               10  ...         8            4         0
# 3         England      5               11  ...         6            5         0
# 4          France      3               22  ...         5            6         0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Step 12. Present only the Shooting Accuracy from England, Italy and Russia

# %%
a_dataframe = pd.DataFrame({"Team": ['England', 'Italy', 'Russia'], "Shooting Accuracy":[53.0,43.0,22.5]})
a_dataframe
# Out:
#       Team  Shooting Accuracy
# 0  England               53.0
# 1    Italy               43.0
# 2   Russia               22.5

# %%
a_df=euro_12[['Team','Shooting Accuracy']]
presenting=a_df.iloc[[3,7,12]]
presenting
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ## Group By

# %% [markdown]
# ## Step 1. Import Data
#
# * sep = "|"

# %%
import pandas as pd
import numpy as np

# %%
df3= pd.read_csv('/content/u.user.txt',sep="|")

# %%
df3.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 2. Discover what is the mean age per occupation

# %%
df3.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 3. Discover the Male ratio per occupation and sort it from the most to the least

# %%
ratio=df3[df3['gender']=='M'].sort_values(by='occupation',ascending=False)
ratio
# Out:
#      user_id  age gender     occupation zip_code
# 740      741   25      M         writer    63108
# 391      392   52      M         writer    59801
# 49        50   21      M         writer    52245
# 497      498   26      M         writer    55408
# 828      829   48      M         writer    80209
# ..       ...  ...    ...            ...      ...
# 818      819   59      M  administrator    40205
# 446      447   30      M  administrator    55113
# 451      452   35      M  administrator    28018
# 802      803   70      M  administrator    78212
# 577      578   31      M  administrator    M7A1A
#
# [670 rows x 5 columns]

# %%
ratio.value_counts()
# Out:
# user_id  age  gender  occupation  zip_code
# 943      22   M       student     77841       1
# 323      21   M       student     19149       1
# 320      19   M       student     24060       1
# 319      38   M       programmer  22030       1
# 318      65   M       retired     06518       1
#                                              ..
# 619      17   M       student     44134       1
# 616      55   M       scientist   50613       1
# 615      38   M       educator    27705       1
# 614      54   M       educator    80227       1
# 1        24   M       technician  85711       1
# Length: 670, dtype: int64

# %% [markdown]
# ### Step 4. For each occupation, calculate the minimum and maximum ages

# %%
df3.groupby('occupation').age.agg({min,max})
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 5. For each combination of occupation and gender, calculate the mean age

# %%
df3.groupby(['occupation','gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 6.  For each occupation present the percentage of women and men

# %%
df3.groupby('occupation').gender.value_counts(normalize=True)*100
# Out:
# occupation     gender
# administrator  M          54.430380
#                F          45.569620
# artist         M          53.571429
#                F          46.428571
# doctor         M         100.000000
# educator       M          72.631579
#                F          27.368421
# engineer       M          97.014925
#                F           2.985075
# entertainment  M          88.888889
#                F          11.111111
# executive      M          90.625000
#                F           9.375000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         M          83.333333
#                F          16.666667
# librarian      F          56.862745
#                M          43.137255
# marketing      M          61.538462
#                F          38.461538
# none           M          55.555556
#                F          44.444444
# ...

# %% [markdown]
# ## SEcond Dataset

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %% [markdown]
# ## Step 1: Run Dataset

# %%
raw_data=pd.DataFrame({'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]})
raw_data
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %% [markdown]
# ### Step 2. What is the mean preTestScore from the regiment Nighthawks?

# %%
raw_data[['preTestScore','postTestScore']].groupby(raw_data['regiment']).mean()
# Out:
#             preTestScore  postTestScore
# regiment
# Dragoons           15.50           61.5
# Nighthawks         15.25           59.5
# Scouts              2.50           66.0

# %% [markdown]
# ### Step 3. Present general statistics by company

# %%
raw_data[['preTestScore','postTestScore']].groupby(raw_data['company']).describe()
# Out:
#         preTestScore                             ... postTestScore
#                count       mean        std  min  ...           25%   50%   75%   max
# company                                          ...
# 1st              6.0   6.666667   8.524475  2.0  ...         34.25  66.0  70.0  94.0
# 2nd              6.0  15.500000  14.652645  2.0  ...         58.25  62.0  68.0  94.0
#
# [2 rows x 16 columns]

# %% [markdown]
# ### Step 4. What is the mean of each company's preTestScore?

# %%
raw_data.groupby('company').preTestScore.mean()
# Out:
# company
# 1st     6.666667
# 2nd    15.500000
# Name: preTestScore, dtype: float64

# %% [markdown]
# ### Step 5. Present the mean preTestScores grouped by regiment and company

# %%
raw_data.groupby(['regiment','company']).preTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %% [markdown]
# ### Step 6. Present the mean preTestScores grouped by regiment and company without heirarchical indexing

# %%
raw_data.groupby(['regiment','company']).preTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %% [markdown]
# ### Step 7. Group the entire dataframe by regiment and company

# %%
raw_data.groupby(['regiment','company']).mean()
# Out:
#                     preTestScore  postTestScore
# regiment   company
# Dragoons   1st               3.5           47.5
#            2nd              27.5           75.5
# Nighthawks 1st              14.0           59.5
#            2nd              16.5           59.5
# Scouts     1st               2.5           66.0
#            2nd               2.5           66.0

# %% [markdown]
# ### Step 8. What is the number of observations in each regiment and company

# %%
#raw_data.groupby(['regiment','company']).mean()
raw_data.groupby(['company','regiment']).preTestScore.count()
# Out:
# company  regiment
# 1st      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# 2nd      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# Name: preTestScore, dtype: int64

# %% [markdown]
# ### Step 09. Iterate over a group and print the name and the whole data from the regiment

# %%
grouped = raw_data.groupby('regiment')

for name, group in grouped:
  print(name)
  print(group)
# Out:
# Dragoons
#    regiment company    name  preTestScore  postTestScore
# 4  Dragoons     1st   Cooze             3             70
# 5  Dragoons     1st   Jacon             4             25
# 6  Dragoons     2nd  Ryaner            24             94
# 7  Dragoons     2nd    Sone            31             57
# Nighthawks
#      regiment company      name  preTestScore  postTestScore
# 0  Nighthawks     1st    Miller             4             25
# 1  Nighthawks     1st  Jacobson            24             94
# 2  Nighthawks     2nd       Ali            31             57
# 3  Nighthawks     2nd    Milner             2             62
# Scouts
#    regiment company   name  preTestScore  postTestScore
# 8    Scouts     1st  Sloan             2             62
# 9    Scouts     1st  Piger             3             70
# 10   Scouts     2nd  Riani             2             62
# 11   Scouts     2nd    Ali             3             70

# %% [markdown]
# ## Apply Function

# %%
import pandas as pd
import numpy as np

# %%
df4= pd.read_csv('/content/US_Crime_Rates_1960_2014.csv')
df4
# Out:
#     Year  Population     Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0   1960   179323175   3384200  ...    912100        1855400         328200
# 1   1961   182992000   3488000  ...    949600        1913000         336000
# 2   1962   185771000   3752200  ...    994300        2089600         366800
# 3   1963   188483000   4109500  ...   1086400        2297800         408300
# 4   1964   191141000   4564600  ...   1213200        2514400         472800
# 5   1965   193526000   4739400  ...   1282500        2572600         496900
# 6   1966   195576000   5223500  ...   1410100        2822000         561200
# 7   1967   197457000   5903400  ...   1632100        3111600         659800
# 8   1968   199399000   6720200  ...   1858900        3482700         783600
# 9   1969   201385000   7410900  ...   1981900        3888600         878500
# 10  1970   203235298   8098000  ...   2205000        4225800         928400
# ...

# %% [markdown]
# ### Step 2. What is the type of the columns?

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
total=len(df4.dtypes)
print("Total column",total)
# Out:
# Total column 12

# %%
df4
# Out:
#     Year  Population     Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0   1960   179323175   3384200  ...    912100        1855400         328200
# 1   1961   182992000   3488000  ...    949600        1913000         336000
# 2   1962   185771000   3752200  ...    994300        2089600         366800
# 3   1963   188483000   4109500  ...   1086400        2297800         408300
# 4   1964   191141000   4564600  ...   1213200        2514400         472800
# 5   1965   193526000   4739400  ...   1282500        2572600         496900
# 6   1966   195576000   5223500  ...   1410100        2822000         561200
# 7   1967   197457000   5903400  ...   1632100        3111600         659800
# 8   1968   199399000   6720200  ...   1858900        3482700         783600
# 9   1969   201385000   7410900  ...   1981900        3888600         878500
# 10  1970   203235298   8098000  ...   2205000        4225800         928400
# ...

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 3. Convert the type of the column Year to datetime64

# %%
pd.to_datetime(df4['Year'], unit='s')
# Out:
# 0    1970-01-01 00:32:40
# 1    1970-01-01 00:32:41
# 2    1970-01-01 00:32:42
# 3    1970-01-01 00:32:43
# 4    1970-01-01 00:32:44
# 5    1970-01-01 00:32:45
# 6    1970-01-01 00:32:46
# 7    1970-01-01 00:32:47
# 8    1970-01-01 00:32:48
# 9    1970-01-01 00:32:49
# 10   1970-01-01 00:32:50
# 11   1970-01-01 00:32:51
# 12   1970-01-01 00:32:52
# 13   1970-01-01 00:32:53
# 14   1970-01-01 00:32:54
# 15   1970-01-01 00:32:55
# 16   1970-01-01 00:32:56
# 17   1970-01-01 00:32:57
# 18   1970-01-01 00:32:58
# 19   1970-01-01 00:32:59
# 20   1970-01-01 00:33:00
# 21   1970-01-01 00:33:01
# 22   1970-01-01 00:33:02
# 23   1970-01-01 00:33:03
# 24   1970-01-01 00:33:04
# 25   1970-01-01 00:33:05
# 26   1970-01-01 00:33:06
# 27   1970-01-01 00:33:07
# 28   1970-01-01 00:33:08
# 29   1970-01-01 00:33:09
# 30   1970-01-01 00:33:10
# 31   1970-01-01 00:33:11
# 32   1970-01-01 00:33:12
# 33   1970-01-01 00:33:13
# 34   1970-01-01 00:33:14
# 35   1970-01-01 00:33:15
# 36   1970-01-01 00:33:16
# ...

# %% [markdown]
# ### Step 4. Set the Year column as the index of the dataframe

# %%
df4.set_index("Year")
# Out:
#       Population     Total  Violent  ...  Burglary  Larceny_Theft  Vehicle_Theft
# Year                                 ...
# 1960   179323175   3384200   288460  ...    912100        1855400         328200
# 1961   182992000   3488000   289390  ...    949600        1913000         336000
# 1962   185771000   3752200   301510  ...    994300        2089600         366800
# 1963   188483000   4109500   316970  ...   1086400        2297800         408300
# 1964   191141000   4564600   364220  ...   1213200        2514400         472800
# 1965   193526000   4739400   387390  ...   1282500        2572600         496900
# 1966   195576000   5223500   430180  ...   1410100        2822000         561200
# 1967   197457000   5903400   499930  ...   1632100        3111600         659800
# 1968   199399000   6720200   595010  ...   1858900        3482700         783600
# 1969   201385000   7410900   661870  ...   1981900        3888600         878500
# ...

# %% [markdown]
# ### Step 5. Delete the Total column

# %%
del df4['Total']

# %%
df4.head()
# Out:
#    Year  Population  Violent  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0  1960   179323175   288460  ...    912100        1855400         328200
# 1  1961   182992000   289390  ...    949600        1913000         336000
# 2  1962   185771000   301510  ...    994300        2089600         366800
# 3  1963   188483000   316970  ...   1086400        2297800         408300
# 4  1964   191141000   364220  ...   1213200        2514400         472800
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Step 6. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
values = df4.groupby('Population')
values.sum()
# Out:
#             Year  Violent  Property  ...  Burglary  Larceny_Theft  Vehicle_Theft
# Population                           ...
# 179323175   1960   288460   3095700  ...    912100        1855400         328200
# 182992000   1961   289390   3198600  ...    949600        1913000         336000
# 185771000   1962   301510   3450700  ...    994300        2089600         366800
# 188483000   1963   316970   3792500  ...   1086400        2297800         408300
# 191141000   1964   364220   4200400  ...   1213200        2514400         472800
# 193526000   1965   387390   4352000  ...   1282500        2572600         496900
# 195576000   1966   430180   4793300  ...   1410100        2822000         561200
# 197457000   1967   499930   5403500  ...   1632100        3111600         659800
# 199399000   1968   595010   6125200  ...   1858900        3482700         783600
# 201385000   1969   661870   6749000  ...   1981900        3888600         878500
# ...

# %% [markdown]
# ### Step 7. What is the most dangerous decade to live in the US?

# %%
df4.sort_values(by=["Population", 'Violent','Property','Murder','Forcible_Rape','Robbery','Aggravated_assault','Burglary','Larceny_Theft','Vehicle_Theft'],
        ascending=[False,False,False,False,False,False,False,False,False,False],ignore_index=True).head()
# Out:
#    Year  Population     Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0  2014   318857056   9475816  ...   1729806        5858496         689527
# 1  2013   316497531   9850445  ...   1931835        6018632         700294
# 2  2012   313873685  10219059  ...   2109932        6168874         723186
# 3  2011   311587816  10258774  ...   2185140        6151095         716508
# 4  2010   309330219  10363873  ...   2168457        6204601         739565
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Stats

# %%
import pandas as pd

# %%
df5= pd.read_csv('/content/US_Baby_Names_right.csv')

# %% [markdown]
# ### Step 2. Assign it to a variable called baby_names.

# %%
baby_names = df5
baby_names.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 1. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 3. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.rename(columns={"Unnamed: 0":"New_column"},inplace=True)

# %%
baby_names.head(1)
# Out:
#    New_column     Id  Name  Year Gender State  Count
# 0       11349  11350  Emma  2004      F    AK     62

# %%
del baby_names['New_column']

# %%
del baby_names['Id']

# %%
baby_names.head(1)
# Out:
#    Name  Year Gender State  Count
# 0  Emma  2004      F    AK     62

# %% [markdown]
# ### Step 4. Are there more male or female names in the dataset?

# %%
baby_names['Gender'].value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %% [markdown]
# ### Step 5. Group the dataset by name and assign to names

# %%
# group the data
names = baby_names.groupby("Name").sum()

# print the first 5 observations
names.head()

# print the size of the dataset
print(names.shape)

# sort it from the biggest value to the smallest one
names.sort_values("Count", ascending = 0).head()
# Out:
# (17632, 2)
#              Year   Count
# Name
# Jacob     1141099  242874
# Emma      1137085  214852
# Michael   1161152  214405
# Ethan     1139091  209277
# Isabella  1137090  204798

# %% [markdown]
# ### Step 6. How many different names exist in the dataset?

# %%
len(baby_names.Name.value_counts())
# Out:
# 17632

# %% [markdown]
# ### Step 7. What is the name with most occurrences?

# %%
names[names.Count == names.Count.max()]
# Out:
#           Year   Count
# Name
# Jacob  1141099  242874

# %% [markdown]
# ### Step 8. How many different names have the least occurrences?

# %%
least_occurance=names[names.Count == names.Count.min()]

# %%
least_occurance.count()
# Out:
# Year     2578
# Count    2578
# dtype: int64

# %% [markdown]
# ### Step 9. What is the median name occurrence?

# %%
#names['Name'].value_counts()[names['Name'].value_counts() == names['Name'].value_counts().max()]
names[names.Count==names.Count.median()]
# Out:
#           Year  Count
# Name
# Aishani  14078     49
# Alara    16079     49
# Alysse   16057     49
# Ameir    16086     49
# Anely    16071     49
# ...        ...    ...
# Sriram   14054     49
# Trinton  16069     49
# Vita     14075     49
# Yoni     16060     49
# Zuleima  14050     49
#
# [66 rows x 2 columns]

# %% [markdown]
# ### Step 10. What is the standard deviation of names?

# %%
names.Count.std()
# Out:
# 11006.069467891111

# %% [markdown]
# ### Step 12. Get a summary with the mean, min, max, std and quartiles.

# %%
baby_names.describe()
# Out:
#                Year         Count
# count  1.016395e+06  1.016395e+06
# mean   2.009053e+03  3.485012e+01
# std    3.138293e+00  9.739735e+01
# min    2.004000e+03  5.000000e+00
# 25%    2.006000e+03  7.000000e+00
# 50%    2.009000e+03  1.100000e+01
# 75%    2.012000e+03  2.600000e+01
# max    2.014000e+03  4.167000e+03

# %% [markdown]
# ## Bonus
#
# Stats

# %% [markdown]
# ## Merger

# %%
import pandas as pd
import numpy as np

# %%
datas = pd.read_csv('/content/US_Crime_Rates_1960_2014.csv')

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
crime = datas
crime.head()
# Out:
#    Year  Population    Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0  1960   179323175  3384200  ...    912100        1855400         328200
# 1  1961   182992000  3488000  ...    949600        1913000         336000
# 2  1962   185771000  3752200  ...    994300        2089600         366800
# 3  1963   188483000  4109500  ...   1086400        2297800         408300
# 4  1964   191141000  4564600  ...   1213200        2514400         472800
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
pd.to_datetime(crime['Year'], unit='s')
# Out:
# 0    1970-01-01 00:32:40
# 1    1970-01-01 00:32:41
# 2    1970-01-01 00:32:42
# 3    1970-01-01 00:32:43
# 4    1970-01-01 00:32:44
# 5    1970-01-01 00:32:45
# 6    1970-01-01 00:32:46
# 7    1970-01-01 00:32:47
# 8    1970-01-01 00:32:48
# 9    1970-01-01 00:32:49
# 10   1970-01-01 00:32:50
# 11   1970-01-01 00:32:51
# 12   1970-01-01 00:32:52
# 13   1970-01-01 00:32:53
# 14   1970-01-01 00:32:54
# 15   1970-01-01 00:32:55
# 16   1970-01-01 00:32:56
# 17   1970-01-01 00:32:57
# 18   1970-01-01 00:32:58
# 19   1970-01-01 00:32:59
# 20   1970-01-01 00:33:00
# 21   1970-01-01 00:33:01
# 22   1970-01-01 00:33:02
# 23   1970-01-01 00:33:03
# 24   1970-01-01 00:33:04
# 25   1970-01-01 00:33:05
# 26   1970-01-01 00:33:06
# 27   1970-01-01 00:33:07
# 28   1970-01-01 00:33:08
# 29   1970-01-01 00:33:09
# 30   1970-01-01 00:33:10
# 31   1970-01-01 00:33:11
# 32   1970-01-01 00:33:12
# 33   1970-01-01 00:33:13
# 34   1970-01-01 00:33:14
# 35   1970-01-01 00:33:15
# 36   1970-01-01 00:33:16
# ...

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime.set_index("Year")
# Out:
#       Population     Total  Violent  ...  Burglary  Larceny_Theft  Vehicle_Theft
# Year                                 ...
# 1960   179323175   3384200   288460  ...    912100        1855400         328200
# 1961   182992000   3488000   289390  ...    949600        1913000         336000
# 1962   185771000   3752200   301510  ...    994300        2089600         366800
# 1963   188483000   4109500   316970  ...   1086400        2297800         408300
# 1964   191141000   4564600   364220  ...   1213200        2514400         472800
# 1965   193526000   4739400   387390  ...   1282500        2572600         496900
# 1966   195576000   5223500   430180  ...   1410100        2822000         561200
# 1967   197457000   5903400   499930  ...   1632100        3111600         659800
# 1968   199399000   6720200   595010  ...   1858900        3482700         783600
# 1969   201385000   7410900   661870  ...   1981900        3888600         878500
# ...

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
del crime["Total"]
crime.head(1)
# Out:
#    Year  Population  Violent  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0  1960   179323175   288460  ...    912100        1855400         328200
#
# [1 rows x 11 columns]

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
values=crime.groupby('Year').Population
values.sum()
# Out:
# Year
# 1960    179323175
# 1961    182992000
# 1962    185771000
# 1963    188483000
# 1964    191141000
# 1965    193526000
# 1966    195576000
# 1967    197457000
# 1968    199399000
# 1969    201385000
# 1970    203235298
# 1971    206212000
# 1972    208230000
# 1973    209851000
# 1974    211392000
# 1975    213124000
# 1976    214659000
# 1977    216332000
# 1978    218059000
# 1979    220099000
# 1980    225349264
# 1981    229146000
# 1982    231534000
# 1983    233981000
# 1984    236158000
# 1985    238740000
# 1986    240132887
# 1987    242282918
# 1988    245807000
# 1989    248239000
# 1990    248709873
# 1991    252177000
# 1992    255082000
# 1993    257908000
# 1994    260341000
# 1995    262755000
# 1996    265228572
# 1997    267637000
# 1998    270296000
# 1999    272690813
# 2000    281421906
# 2001    285317559
# 2002    287973924
# 2003    290690788
# 2004    293656842
# 2005    296507061
# 2006    299398484
# 2007    301621157
# 2008    304374846
# ...

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
crime.sort_values(by=["Year", 'Violent','Property','Murder','Forcible_Rape','Robbery','Aggravated_assault','Burglary','Larceny_Theft','Vehicle_Theft'],
        ascending=[False,False,False,False,False,False,False,False,False,False],ignore_index=True)
# Out:
#     Year  Population  Violent  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0   2014   318857056  1197987  ...   1729806        5858496         689527
# 1   2013   316497531  1199684  ...   1931835        6018632         700294
# 2   2012   313873685  1217067  ...   2109932        6168874         723186
# 3   2011   311587816  1206031  ...   2185140        6151095         716508
# 4   2010   309330219  1251248  ...   2168457        6204601         739565
# 5   2009   307006550  1325896  ...   2203313        6338095         795652
# 6   2008   304374846  1392628  ...   2228474        6588046         958629
# 7   2007   301621157  1408337  ...   2176140        6568572        1095769
# 8   2006   299398484  1418043  ...   2183746        6607013        1192809
# 9   2005   296507061  1390745  ...   2155448        6783447        1235859
# 10  2004   293656842  1360088  ...   2144446        6937089        1237851
# ...

# %% [markdown]
# ## Stats

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/wind.data',sep = "\s+", parse_dates = [[0,1,2]])
data.head(5)
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL  ...    CLA    MUL    CLO    BEL    MAL
# 0 2061-01-01  15.04  14.96  13.17   9.29  ...  10.25  10.83  12.58  18.50  15.04
# 1 2061-01-02  14.71    NaN  10.83   6.50  ...  10.04   9.79   9.67  17.54  13.83
# 2 2061-01-03  18.50  16.88  12.33  10.13  ...    NaN   8.50   7.67  12.75  12.71
# 3 2061-01-04  10.58   6.63  11.75   4.58  ...   1.79   5.83   5.88   5.46  10.88
# 4 2061-01-05  13.33  13.25  11.42   6.17  ...   6.54  10.92  10.34  12.92  11.83
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
import datetime
# function that uses datetime
def fix_century(x):
  year = x.year - 100 if x.year > 1989 else x.year
  return datetime.date(year, x.month, x.day)

# apply the function fix_century on the column and replace the values to the right ones
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix_century)

# data.info()
data.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL  ...    CLA    MUL    CLO    BEL    MAL
# 0  1961-01-01  15.04  14.96  13.17   9.29  ...  10.25  10.83  12.58  18.50  15.04
# 1  1961-01-02  14.71    NaN  10.83   6.50  ...  10.04   9.79   9.67  17.54  13.83
# 2  1961-01-03  18.50  16.88  12.33  10.13  ...    NaN   8.50   7.67  12.75  12.71
# 3  1961-01-04  10.58   6.63  11.75   4.58  ...   1.79   5.83   5.88   5.46  10.88
# 4  1961-01-05  13.33  13.25  11.42   6.17  ...   6.54  10.92  10.34  12.92  11.83
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index('Yr_Mo_Dy')
# Out:
#               RPT    VAL    ROS    KIL  ...    MUL    CLO    BEL    MAL
# Yr_Mo_Dy                                ...
# 1961-01-01  15.04  14.96  13.17   9.29  ...  10.83  12.58  18.50  15.04
# 1961-01-02  14.71    NaN  10.83   6.50  ...   9.79   9.67  17.54  13.83
# 1961-01-03  18.50  16.88  12.33  10.13  ...   8.50   7.67  12.75  12.71
# 1961-01-04  10.58   6.63  11.75   4.58  ...   5.83   5.88   5.46  10.88
# 1961-01-05  13.33  13.25  11.42   6.17  ...  10.92  10.34  12.92  11.83
# ...           ...    ...    ...    ...  ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  ...  14.04  14.00  17.21  40.08
# 1978-12-28  13.21   5.46  13.46   5.00  ...  15.25  18.05  21.79  41.46
# 1978-12-29  14.00  10.29  14.42   8.71  ...  14.50  16.42  18.88  29.58
# 1978-12-30  18.50  14.04  21.29   9.13  ...  12.46  12.12  14.67  28.79
# 1978-12-31  20.33  17.41  27.29   9.59  ...  11.58  11.38  12.08  22.08
#
# [6574 rows x 12 columns]

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# Yr_Mo_Dy    0
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.notnull().sum()
# Out:
# Yr_Mo_Dy    6574
# RPT         6568
# VAL         6571
# ROS         6572
# KIL         6569
# SHA         6572
# BIR         6574
# DUB         6571
# CLA         6572
# MUL         6571
# CLO         6573
# BEL         6574
# MAL         6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats=data.describe()
loc_stats
# Out:
#                RPT          VAL  ...          BEL          MAL
# count  6568.000000  6571.000000  ...  6574.000000  6570.000000
# mean     12.362987    10.644314  ...    13.121007    15.599079
# std       5.618413     5.267356  ...     5.835037     6.699794
# min       0.670000     0.210000  ...     0.130000     0.670000
# 25%       8.120000     6.670000  ...     8.710000    10.710000
# 50%      11.710000    10.170000  ...    12.500000    15.000000
# 75%      15.920000    14.040000  ...    16.880000    19.830000
# max      35.800000    33.370000  ...    42.380000    42.540000
#
# [8 rows x 12 columns]

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats = data.groupby('Yr_Mo_Dy').agg({'mean',min,max,'std'})
day_stats
# Out:
#               RPT                      VAL  ...    BEL    MAL
#               min    max std   mean    min  ...   mean    min    max std   mean
# Yr_Mo_Dy                                    ...
# 1961-01-01  15.04  15.04 NaN  15.04  14.96  ...  18.50  15.04  15.04 NaN  15.04
# 1961-01-02  14.71  14.71 NaN  14.71    NaN  ...  17.54  13.83  13.83 NaN  13.83
# 1961-01-03  18.50  18.50 NaN  18.50  16.88  ...  12.75  12.71  12.71 NaN  12.71
# 1961-01-04  10.58  10.58 NaN  10.58   6.63  ...   5.46  10.88  10.88 NaN  10.88
# 1961-01-05  13.33  13.33 NaN  13.33  13.25  ...  12.92  11.83  11.83 NaN  11.83
# ...           ...    ...  ..    ...    ...  ...    ...    ...    ...  ..    ...
# 1978-12-27  17.58  17.58 NaN  17.58  16.96  ...  17.21  40.08  40.08 NaN  40.08
# 1978-12-28  13.21  13.21 NaN  13.21   5.46  ...  21.79  41.46  41.46 NaN  41.46
# 1978-12-29  14.00  14.00 NaN  14.00  10.29  ...  18.88  29.58  29.58 NaN  29.58
# ...

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data.groupby('Yr_Mo_Dy').mean().mean()
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
day_stats = data.groupby('Yr_Mo_Dy').agg({'mean',min,max,'std'})
day_stats
# Out:
#               RPT                      VAL  ...    BEL    MAL
#               min    max std   mean    min  ...   mean    min    max std   mean
# Yr_Mo_Dy                                    ...
# 1961-01-01  15.04  15.04 NaN  15.04  14.96  ...  18.50  15.04  15.04 NaN  15.04
# 1961-01-02  14.71  14.71 NaN  14.71    NaN  ...  17.54  13.83  13.83 NaN  13.83
# 1961-01-03  18.50  18.50 NaN  18.50  16.88  ...  12.75  12.71  12.71 NaN  12.71
# 1961-01-04  10.58  10.58 NaN  10.58   6.63  ...   5.46  10.88  10.88 NaN  10.88
# 1961-01-05  13.33  13.33 NaN  13.33  13.25  ...  12.92  11.83  11.83 NaN  11.83
# ...           ...    ...  ..    ...    ...  ...    ...    ...    ...  ..    ...
# 1978-12-27  17.58  17.58 NaN  17.58  16.96  ...  17.21  40.08  40.08 NaN  40.08
# 1978-12-28  13.21  13.21 NaN  13.21   5.46  ...  21.79  41.46  41.46 NaN  41.46
# 1978-12-29  14.00  14.00 NaN  14.00  10.29  ...  18.88  29.58  29.58 NaN  29.58
# ...
