# %%
import pandas as pd

# %%
df = pd.read_csv('Crime_estimated_data.csv')

# %%
df.head(50)
# Out:
#     year    province  violent_crime  homicide  rape_legacy  rape_revised  \
# 0   1995      punjab        1798792     21606        97470         97470
# 1   1996      punjab        1688540     19645        96252         96252
# 2   1997      punjab        1636099     18211        96153         96153
# 3   1998      punjab        1533887     16974        93144         93144
# 4   1999      punjab        1426044     15522        89411         89411
# 5   2000      punjab        1425486     15586        90178         90178
# 6   2001      punjab        1439480     16037        90863         90863
# 7   2002      punjab        1423677     16229        95235         95235
# 8   2003      punjab        1383676     16528        93883         93883
# 9   2004      punjab        1360088     16148        95089         95089
# 10  2005      punjab        1390745     16740        94347         94347
# 11  2006      punjab        1435123     17309        94472         94472
# ...

# %%
df = pd.DataFrame({
    'violent_crime':[1798792,1688540,1636099,1533887,1426044,1425486,1439480,1423677,1383676,1360088],
    'homicide':[21606,19645,18211,16974,15522,15586,16037,16229,16528,16148],
    'rape_legacy':[97470,96252,96153,93144,89411,90178,90863,95235,93883,95089],
    'rape_revised':[97470,96252,96153,93144,89411,90178,90863,95235,93883,9508947],
    'robbery':[580509,535594,498534,447186,409371,408016,423557,420806,414235,401470],
    'aggravated_assault':[1099207,1037049,1023201,976583,911740,911706,909023,891407,859030,847381],
    'property_crime':[12063935,11805323,11558975,10951827,10208334,10182584,10437189,10455277,10442862,10319386],
    'burglary':[2593784,2506400,2461026,2332735,2100739,2050992,2116531,2151252,2154834,2144446],
    'larceny':[7997710,7904685,7743760,7376311,6955520,6971590,7092267,7057379,7026802,6937089],
    'province':['punjab','punjab','sindh','sindh','balochitan','balochitan','kpk','kpk','kpk','kpk'],
    'motor_vehicle_theft':[1472441,1394238,1354189,1242781,1152075,1160002,1228391,1246646,1261226,1237851],
    'year':[1995,1996,1997,1998,1999,2000,2001,2002,2003,2004]
})

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='violent_crime')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='motor_vehicle_theft')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='larceny')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='burglary')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='property_crime')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='aggravated_assault')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='robbery')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='rape_revised')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='rape_legacy')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='area',x='province',y='homicide')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='violent_crime',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='homicide',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='rape_legacy',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='rape_revised',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='robbery',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='aggravated_assault',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='property_crime',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='burglary',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='larceny',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='line',x='motor_vehicle_theft',y='year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='bar',x='larceny',y='year')
plt.show()
